# %%
import os

# %%
dir_JPG = os.listdir('./datasets/pascal_voc_seg/VOCdevkit/VOC2012/JPEGImages')
dir_JPG.sort()
dir_Seg = os.listdir('./datasets/pascal_voc_seg/VOCdevkit/VOC2012/SegmentationClassRaw')
dir_Seg.sort()

# %%
len(dir_Seg)
# Out:
# 42

# %%
from random import shuffle

# %%
print(dir_JPG)
# Out:
# ['1.png', '10.png', '11.png', '12.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '2.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '3.png', '30.png', '31.png', '32.png', '33.png', '34.png', '35.png', '36.png', '37.png', '38.png', '39.png', '4.png', '40.png', '41.png', '42.png', '43.png', '5.png', '6.png', '7.png', '8.png', '9.png']

# %%
shuffle(dir_JPG)

# %%
print(dir_JPG)
# Out:
# ['26.png', '35.png', '43.png', '28.png', '29.png', '37.png', '36.png', '8.png', '1.png', '16.png', '42.png', '38.png', '10.png', '41.png', '15.png', '25.png', '23.png', '31.png', '20.png', '39.png', '40.png', '21.png', '30.png', '32.png', '12.png', '22.png', '5.png', '6.png', '4.png', '9.png', '2.png', '11.png', '14.png', '3.png', '17.png', '24.png', '34.png', '19.png', '18.png', '33.png', '27.png', '7.png']

# %%
# import cv2
# from matplotlib import pyplot as plt
# for item in dir_JPG:
#     image = cv2.imread('./datasets/pascal_voc_seg/VOCdevkit/VOC2012/JPEGImages/' + item)
#     cv2.imwrite('./datasets/pascal_voc_seg/VOCdevkit/VOC2012/JPEGImages/' + item[5:-3] + 'jpg', image)  
# for item in dir_Seg:    
#     image1 = cv2.imread('./datasets/pascal_voc_seg/VOCdevkit/VOC2012/SegmentationClassRaw/' + item)
#     cv2.imwrite('./datasets/pascal_voc_seg/VOCdevkit/VOC2012/SegmentationClassRaw/' + item[15:], image1)

# %%
# with open('./datasets/pascal_voc_seg/VOCdevkit/VOC2012/ImageSets/Segmentation/train.txt', 'w') as train_file:
#     for i in range(30):
#         train_file.write('JPEGImages/' + dir_JPG[i] + ' SegmentaionClassRaw/' + dir_Seg[i] + '\n')
# with open('./datasets/pascal_voc_seg/VOCdevkit/VOC2012/ImageSets/Segmentation/val.txt', 'w') as val_file:
#     for i in range(30,42):
#         val_file.write('JPEGImages/' + dir_JPG[i] + ' SegmentaionClassRaw/' + dir_Seg[i] + '\n')

# %%
with open('./datasets/pascal_voc_seg/VOCdevkit/VOC2012/ImageSets/Segmentation/train.txt', 'w') as train_file:
    for i in range(30):
        train_file.write(dir_JPG[i][:-4] + '\n')
with open('./datasets/pascal_voc_seg/VOCdevkit/VOC2012/ImageSets/Segmentation/val.txt', 'w') as val_file:
    for i in range(30,42):
        val_file.write(dir_JPG[i][:-4] + '\n')

# %%
import cv2
from matplotlib import pyplot as plt
image = cv2.imread('./datasets/pascal_voc_seg/VOCdevkit/VOC2012/SegmentationClassRaw/1.png', -1)

# %%
# %matplotlib notebook
plt.imshow(image)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# import cv2
# for item in dir_Seg:
#     image = cv2.imread('./datasets/pascal_voc_seg/VOCdevkit/VOC2012/SegmentationClassRaw/' + item)
#     image = image[:,:,0]
#     image[image==50] = 1
#     image[image==150] = 2
#     image[image==255] = 3
#     image[image>3] = 2
#     image = cv2.imwrite('./datasets/pascal_voc_seg/VOCdevkit/VOC2012/SegmentationClassRaw/' + item, image)

# %% [markdown]
# # create tfrecord

# %%
#run python build_voc2012_data.py
